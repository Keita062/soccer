# %% [markdown]
# <a href="https://colab.research.google.com/github/Keita062/soccer/blob/main/%E3%83%87%E3%83%BC%E3%82%BF%E5%8A%A0%E5%B7%A5(11.04).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 読み込むCSVファイルのパスをリスト化
file_paths = [
    "/content/1992.csv", "/content/1993.csv", "/content/1994.csv", "/content/1995.csv",
    "/content/1996.csv", "/content/1997.csv", "/content/1998.csv", "/content/1999.csv",
    "/content/2000.csv", "/content/2001.csv", "/content/2002.csv", "/content/2003.csv",
    "/content/2004.csv", "/content/2005.csv", "/content/2006.csv", "/content/2007.csv",
    "/content/2008.csv", "/content/2009.csv", "/content/2010.csv", "/content/2011.csv",
    "/content/2012.csv", "/content/2013.csv", "/content/2014.csv", "/content/2015.csv",
    "/content/2017.csv", "/content/2018.csv", "/content/2019.csv", "/content/2020.csv"
]

# 各CSVファイルをDataFrameとして読み込み、リストに格納
data_frames = [pd.read_csv(file) for file in file_paths]

# すべてのDataFrameを縦方向に結合
premia = pd.concat(data_frames, ignore_index=True)

# データ確認
premia.head()
# Out:
#    Round             Date             Team 1   FT               Team 2
# 0      1  Sat Aug 15 1992         Arsenal FC  2-4      Norwich City FC
# 1      1  Sat Aug 15 1992    Leeds United FC  2-1         Wimbledon FC
# 2      1  Sat Aug 15 1992   Coventry City FC  2-1     Middlesbrough FC
# 3      1  Sat Aug 15 1992    Ipswich Town FC  1-1       Aston Villa FC
# 4      1  Sat Aug 15 1992  Crystal Palace FC  3-3  Blackburn Rovers FC

# %%
premia = premia.rename(columns = { "Round" : "Section" ,"Team 1" : "Home_Team" , "Team 2" : "Awey_Team" })

# %%
premia["Date"].unique()
# Out:
# array(['Sat Aug 15 1992', 'Sun Aug 16 1992', 'Mon Aug 17 1992', ...,
#        'Tue May 18 2021', 'Wed May 19 2021', 'Sun May 23 2021'],
#       dtype=object)

# %%
# 年に (P) が含まれている行を削除
premia = premia[~premia['Date'].str.contains(r"\d{4}\(P\)", na=False)]

# %%
premia.head()
# Out:
#    Section             Date          Home_Team   FT            Awey_Team
# 0        1  Sat Aug 15 1992         Arsenal FC  2-4      Norwich City FC
# 1        1  Sat Aug 15 1992    Leeds United FC  2-1         Wimbledon FC
# 2        1  Sat Aug 15 1992   Coventry City FC  2-1     Middlesbrough FC
# 3        1  Sat Aug 15 1992    Ipswich Town FC  1-1       Aston Villa FC
# 4        1  Sat Aug 15 1992  Crystal Palace FC  3-3  Blackburn Rovers FC

# %%
# 日付を標準フォーマットに変換
premia['Date'] = pd.to_datetime(premia['Date'], format='%a %b %d %Y')

# %%
premia
# Out:
#        Section       Date          Home_Team   FT            Awey_Team
# 0            1 1992-08-15         Arsenal FC  2-4      Norwich City FC
# 1            1 1992-08-15    Leeds United FC  2-1         Wimbledon FC
# 2            1 1992-08-15   Coventry City FC  2-1     Middlesbrough FC
# 3            1 1992-08-15    Ipswich Town FC  1-1       Aston Villa FC
# 4            1 1992-08-15  Crystal Palace FC  3-3  Blackburn Rovers FC
# ...        ...        ...                ...  ...                  ...
# 10881       38 2021-05-23           West Ham  3–0          Southampton
# 10882       38 2021-05-23       Leeds United  3–1            West Brom
# 10883       38 2021-05-23            Arsenal  2–0             Brighton
# 10884       38 2021-05-23          Liverpool  2–0       Crystal Palace
# 10885       38 2021-05-23             Fulham  0–2        Newcastle Utd
#
# [10874 rows x 5 columns]

# %%
teams = np.array([
    'Manchester United FC', 'Arsenal FC', 'Chelsea FC', 'Liverpool FC',
    'Tottenham Hotspur FC', 'Everton FC', 'Manchester City FC',
    'Newcastle United FC', 'Aston Villa FC', 'West Ham United FC',
    'Blackburn Rovers FC', 'Southampton FC', 'Leeds United FC',
    'Middlesbrough FC', 'Leicester City FC', 'Fulham FC',
    'Sunderland AFC', 'Bolton Wanderers FC', 'Crystal Palace FC',
    'West Bromwich Albion FC', 'Stoke City FC', 'Coventry City FC',
    'Sheffield Wednesday FC', 'Wimbledon FC', 'Norwich City FC',
    'Charlton Athletic FC', 'Wigan Athletic FC',
    'Queens Park Rangers FC', 'Portsmouth FC', 'Birmingham City FC',
    'Derby County FC', 'Swansea City FC', 'Wolverhampton Wanderers FC',
    'Nottingham Forest FC', 'Ipswich Town FC', 'Watford FC',
    'Burnley FC', 'Sheffield United FC', 'AFC Bournemouth',
    'Hull City AFC', 'Reading FC', 'Brighton & Hove Albion FC',
    'Oldham Athletic AFC', 'Cardiff City FC', 'Bradford City AFC',
    'Huddersfield Town AFC', 'Blackpool FC', 'Tottenham', 'West Brom',
    'West Ham', 'Southampton', 'Liverpool', 'Sheffield Utd',
    'Newcastle Utd', 'Aston Villa', 'Brighton', 'Burnley', 'Chelsea',
    'Crystal Palace', 'Everton', 'Fulham', 'Leeds United',
    'Leicester City', 'Arsenal', 'Manchester City', 'Manchester Utd',
    'Wolves', 'Barnsley FC', 'Swindon Town FC'
])

# チーム名の標準化を行う辞書
team_name_mapping = {
    'Manchester United FC': 'Manchester United',
    'Manchester Utd': 'Manchester United',
    'Arsenal FC': 'Arsenal',
    'Arsenal': 'Arsenal',
    'Chelsea FC': 'Chelsea',
    'Chelsea': 'Chelsea',
    'Liverpool FC': 'Liverpool',
    'Liverpool': 'Liverpool',
    'Tottenham Hotspur FC': 'Tottenham Hotspur',
    'Tottenham': 'Tottenham Hotspur',
    'Everton FC': 'Everton',
    'Everton': 'Everton',
    'Manchester City FC': 'Manchester City',
    'Manchester City': 'Manchester City',
    'Newcastle United FC': 'Newcastle United',
    'Newcastle Utd': 'Newcastle United',
    'Aston Villa FC': 'Aston Villa',
    'Aston Villa': 'Aston Villa',
    'West Ham United FC': 'West Ham United',
    'West Ham': 'West Ham United',
    'Southampton FC': 'Southampton',
    'Southampton': 'Southampton',
    'Fulham FC': 'Fulham',
    'Fulham': 'Fulham',
    'Leeds United FC': 'Leeds United',
    'Leeds United': 'Leeds United',
    'Leicester City FC': 'Leicester City',
    'Leicester City': 'Leicester City',
    'Brighton & Hove Albion FC': 'Brighton',
    'Brighton': 'Brighton',
    'Burnley FC': 'Burnley',
    'Burnley': 'Burnley',
    'Wolverhampton Wanderers FC': 'Wolves',
    'Wolves': 'Wolves',
    # 追加のチーム名のマッピングをここに追加できます
}

# %%
premia["Home_Team"] = premia["Home_Team"].replace(team_name_mapping)
premia["Awey_Team"] = premia["Awey_Team"].replace(team_name_mapping)

# %%
premia['Home_Team'].unique()
# Out:
# array(['Arsenal', 'Leeds United', 'Coventry City FC', 'Ipswich Town FC',
#        'Crystal Palace FC', 'Southampton', 'Chelsea',
#        'Sheffield United FC', 'Everton', 'Nottingham Forest FC',
#        'Manchester City', 'Blackburn Rovers FC', 'Wimbledon FC',
#        'Sheffield Wednesday FC', 'Norwich City FC', 'Manchester United',
#        'Liverpool', 'Middlesbrough FC', 'Oldham Athletic AFC',
#        'Aston Villa', 'Tottenham Hotspur', 'Queens Park Rangers FC',
#        'Newcastle United', 'West Ham United', 'Swindon Town FC',
#        'Leicester City', 'Bolton Wanderers FC', 'Derby County FC',
#        'Sunderland AFC', 'Barnsley FC', 'Charlton Athletic FC',
#        'Watford FC', 'Bradford City AFC', 'Fulham',
#        'West Bromwich Albion FC', 'Birmingham City FC', 'Portsmouth FC',
#        'Wolves', 'Wigan Athletic FC', 'Reading FC', 'Hull City AFC',
#        'Stoke City FC', 'Burnley', 'Blackpool FC', 'Swansea City FC',
#        'Cardiff City FC', 'AFC Bournemouth', 'Brighton',
#        'Huddersfield Town AFC', 'Crystal Palace', 'West Brom',
#        'Sheffield Utd'], dtype=object)

# %%
#確認

from os import umask
# home_teamのユニークな値を取得
home_unique = set(premia['Home_Team'].unique())

# away_teamのユニークな値を取得
away_unique = set(premia['Awey_Team'].unique())

# 一致しないチームを取得
unmatched_teams = home_unique.symmetric_difference(away_unique)
unmatched_teams
# Out:
# set()

# %%
premia.head()
# Out:
#    Section       Date          Home_Team   FT            Awey_Team
# 0        1 1992-08-15            Arsenal  2-4      Norwich City FC
# 1        1 1992-08-15       Leeds United  2-1         Wimbledon FC
# 2        1 1992-08-15   Coventry City FC  2-1     Middlesbrough FC
# 3        1 1992-08-15    Ipswich Town FC  1-1          Aston Villa
# 4        1 1992-08-15  Crystal Palace FC  3-3  Blackburn Rovers FC

# %%
premia['FT'] = premia['FT'].str.replace('–', '-', regex=False)
premia[['Home_Score', 'Awey_Score']] = premia['FT'].str.split('-', expand=True)

# %%
premia.head()
# Out:
#    Section       Date          Home_Team   FT            Awey_Team Home_Score  \
# 0        1 1992-08-15            Arsenal  2-4      Norwich City FC          2
# 1        1 1992-08-15       Leeds United  2-1         Wimbledon FC          2
# 2        1 1992-08-15   Coventry City FC  2-1     Middlesbrough FC          2
# 3        1 1992-08-15    Ipswich Town FC  1-1          Aston Villa          1
# 4        1 1992-08-15  Crystal Palace FC  3-3  Blackburn Rovers FC          3
#
#   Awey_Score
# 0          4
# 1          1
# 2          1
# 3          1
# 4          3

# %%
premia.drop('FT', axis=1, inplace=True)
premia.head()
# Out:
#    Section       Date          Home_Team            Awey_Team Home_Score  \
# 0        1 1992-08-15            Arsenal      Norwich City FC          2
# 1        1 1992-08-15       Leeds United         Wimbledon FC          2
# 2        1 1992-08-15   Coventry City FC     Middlesbrough FC          2
# 3        1 1992-08-15    Ipswich Town FC          Aston Villa          1
# 4        1 1992-08-15  Crystal Palace FC  Blackburn Rovers FC          3
#
#   Awey_Score
# 0          4
# 1          1
# 2          1
# 3          1
# 4          3

# %%
premia.to_csv('premia.csv', index=False)
